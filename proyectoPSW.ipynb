# %%
# !pip install wordcloud
# !pip install pandas
# !pip install requests
# !pip install bs4
# !pip install beautifulsoup4

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import string
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
from bs4 import BeautifulSoup
import requests
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

l= input("Ingrese la id: ")
n= "/anythingg?tab=tags&sort=votes&page=1"
w = "https://es.stackoverflow.com/users/"
url = w+l+str(n)
page = requests.get (url)
soup = BeautifulSoup(page.content, 'html.parser')

gg= soup.find_all('a', class_= 'post-tag')


etiquetas = list ()

for i in gg:
    etiquetas.append(i.text)

etiquetas.pop(0)

gt= soup.find_all('div', class_= 'answer-votes')

count = 1
numeros = list ()

for i in gt:
    numeros.append(i.text)


datos = {'Nombre': etiquetas, 'Puntos': numeros}
df = pd.DataFrame({'Nombre': etiquetas, 'Puntos': numeros})
df.to_csv('Gg.csv', index=False)
#print (df)
df.to_csv('Gg.csv', index=False)

text = pd.read_csv("Gg.csv")

df[['Nombre', 'Puntos']].head()

textvar = ' '.join(df['Nombre'].tolist())

wordcloud = WordCloud(background_color='black', width=3000,height=2000,stopwords=STOPWORDS).generate(textvar)

plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

print (df)
# Out:
# Ingrese la id: 206458
#                Nombre Puntos
# 0          javascript     60
# 1                 css      3
# 2               excel      2
# 3               style      1
# 4                html     20
# 5                 dom      3
# 6               mysql      1
# 7            firebase      1
# 8                 php     19
# 9           .htaccess      3
# 10               date      1
# 11        material-ui      1
# 12             jquery     11
# 13       diccionarios      3
# 14            reactjs      1
# 15             script      0
# 16             python      7
# 17                nlp      3
# 18               css3      1
# 19         phpmyadmin      0
# 20              input      7
# 21           angular8      3
# 22             iframe      1
# 23              email      0
# 24               json      6
# 25         python-3.x      3
# 26            session      1
# 27         validación      0
# 28               ajax      6
# 29              array      2
# ...
